# %% [markdown]
# Aula 01

# %%
from IPython.display import HTML

HTML("""
<style>

body {
    background: #fff6fb;
}

/* ----------- HEADER GLOBAL ------------ */

#chanah-header {
    font-family: Georgia, "Times New Roman", serif;
    background: linear-gradient(90deg, #8c2358, #c7639f);
    color: white;
    padding: 18px 20px;
    border-radius: 10px;
    margin-bottom: 18px;
}

#chanah-header h1 {
    font-size: 26px;
    margin: 0;
}

#chanah-header h2 {
    font-size: 14px;
    margin: 3px 0 0 0;
    font-weight: normal;
    opacity: 0.9;
}

</style>

<div id="chanah-header">
   <h1>Chanah — Caderno de Física Matemática</h1>
   <h2>Instituto de Física • Quantum Computing • Teoria de Grupos</h2>
</div>
""")
# Out:
# <style>
#
# body {
#     background: #fff6fb;
# }
#
# /* ----------- HEADER GLOBAL ------------ */
#
# #chanah-header {
#     font-family: Georgia, "Times New Roman", serif;
#     background: linear-gradient(90deg, #8c2358, #c7639f);
#     color: white;
#     padding: 18px 20px;
#     border-radius: 10px;
#     margin-bottom: 18px;
# }
#
# #chanah-header h1 {
#     font-size: 26px;
#     margin: 0;
# }
#
# #chanah-header h2 {
#     font-size: 14px;
#     margin: 3px 0 0 0;
#     font-weight: normal;
#     opacity: 0.9;
# }
#
# </style>
#
# <div id="chanah-header">
#    <h1>Chanah — Caderno de Física Matemática</h1>
#    <h2>Instituto de Física • Quantum Computing • Teoria de Grupos</h2>
# </div>

# %% [markdown]
# # Teste
