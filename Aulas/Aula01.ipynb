# %% [markdown]
# Aula 01

# %%
from IPython.display import HTML

HTML("""
<style>

/* Fundo da página inteira (fora do retângulo grande) */
html, body {
    background-color: #ffeef7;  /* rosa bem clarinho */
}

/* Retângulo grande do notebook (o que ainda está branco no seu print) */
.container,
#notebook-container {
    background-color: #ffeef7;   /* rosa clarinho */
    border-radius: 24px;
    padding: 32px;
    margin: 40px auto;
    box-shadow: 0 10px 30px rgba(0,0,0,0.05);
}

/* Cada célula */
.cell {
    background-color: #ffeef7;   /* mais rosinha */
    border-radius: 18px;
    padding: 16px 20px;
    margin: 16px 0;
}

/* Área de saída */
.output_area {
    background-color: #fef1f7;
    border-radius: 12px;
    padding: 10px 14px;
}

/* Markdown não precisa criar outro fundo branco */
.rendered_html {
    background-color: transparent !important;
}

/* Garantia extra para variantes de template */
.jp-Notebook,
.jp-NotebookPanel {
    background-color: transparent !important;
}

</style>

<div id="chanah-header">
   <h1>Chanah — Caderno de Física Matemática</h1>
   <h2>Instituto de Física • Quantum Computing • Teoria de Grupos</h2>
</div>
""")
# Out:
# <style>
#
# /* Fundo da página inteira (fora do retângulo grande) */
# html, body {
#     background-color: #ffeef7;  /* rosa bem clarinho */
# }
#
# /* Retângulo grande do notebook (o que ainda está branco no seu print) */
# .container,
# #notebook-container {
#     background-color: #ffeef7;   /* rosa clarinho */
#     border-radius: 24px;
#     padding: 32px;
#     margin: 40px auto;
#     box-shadow: 0 10px 30px rgba(0,0,0,0.05);
# }
#
# /* Cada célula */
# .cell {
#     background-color: #ffeef7;   /* mais rosinha */
#     border-radius: 18px;
#     padding: 16px 20px;
#     margin: 16px 0;
# }
#
# /* Área de saída */
# .output_area {
#     background-color: #fef1f7;
#     border-radius: 12px;
#     padding: 10px 14px;
# }
#
# /* Markdown não precisa criar outro fundo branco */
# .rendered_html {
#     background-color: transparent !important;
# }
#
# /* Garantia extra para variantes de template */
# .jp-Notebook,
# .jp-NotebookPanel {
# ...

# %% [markdown]
# # Teste
